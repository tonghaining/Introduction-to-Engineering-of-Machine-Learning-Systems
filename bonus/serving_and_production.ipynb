# %% [markdown]
# # Deploying models to production
# Ask for the instructors to deploy the Kubernetes settings to your cluster.
#
# Set `RUN_ID` and `MODEL_NAME` in the cells below before applying `bonus/wine-model.yaml`.

# %%
import requests
import time

# %%
from pathlib import Path
import mlflow
import yaml

# Fill this with the run ID from MLflow.
RUN_ID = "your-run-id-here"

candidate_paths = [Path("bonus/wine-model.yaml"), Path("wine-model.yaml")]
MANIFEST_PATH = next((path for path in candidate_paths if path.exists()), candidate_paths[0])
MANIFEST_FILE = str(MANIFEST_PATH)

def update_storage_uri_from_run_id(run_id, artifact_path="model"):
    run = mlflow.get_run(run_id)
    storage_uri = f"{run.info.artifact_uri.rstrip('/')}/{artifact_path}"

    manifest = yaml.safe_load(MANIFEST_PATH.read_text())
    manifest["spec"]["predictor"]["model"]["storageUri"] = storage_uri
    MANIFEST_PATH.write_text(yaml.safe_dump(manifest, sort_keys=False))

    return storage_uri

STORAGE_URI = update_storage_uri_from_run_id(RUN_ID)
print(f"Updated {MANIFEST_FILE}: storageUri={STORAGE_URI}")

# %%
from pathlib import Path
import yaml

# Pick a unique Kubernetes model name before applying the manifest.
#MODEL_NAME = "your-model-name-here"

candidate_paths = [Path("bonus/wine-model.yaml"), Path("wine-model.yaml")]
MANIFEST_PATH = next((path for path in candidate_paths if path.exists()), candidate_paths[0])
MANIFEST_FILE = str(MANIFEST_PATH)

manifest = yaml.safe_load(MANIFEST_PATH.read_text())
manifest["metadata"]["name"] = MODEL_NAME
MANIFEST_PATH.write_text(yaml.safe_dump(manifest, sort_keys=False))

print(f"Updated {MANIFEST_FILE}: metadata.name={MODEL_NAME}")

# %%
# Add the model s3 path to the manifest first.
# !kubectl apply -f {MANIFEST_FILE}

# %%
# MODEL_NAME is written into the manifest above.
# let's check its running now
# !kubectl get isvc {MODEL_NAME} -n kserve-inference
# waiting version
#!kubectl get isvc {MODEL_NAME} -n kserve-inference -w

# %%
# check pods
# !kubectl get pods -n kserve-inference -l serving.kserve.io/inferenceservice={MODEL_NAME}

# %%
# check pods again
# !kubectl get pods -n kserve-inference -l serving.kserve.io/inferenceservice={MODEL_NAME}

# %%
# let's check status one more time if it's running now
# !kubectl get isvc {MODEL_NAME} -n kserve-inference

# %%
# load data from data/2_data_train.csv
import pandas as pd
data = pd.read_csv("data/2_data_train.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           11.9             0.380         0.51             2.0      0.121
# 1            7.5             0.725         0.04             1.5      0.076
# 2           11.5             0.300         0.60             2.0      0.067
# 3            8.3             0.650         0.10             2.9      0.089
# 4            6.4             0.530         0.09             3.9      0.123
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  7.0                  20.0  0.99960  3.24       0.76
# 1                  8.0                  15.0  0.99508  3.26       0.53
# 2                 12.0                  27.0  0.99810  3.11       0.97
# 3                 17.0                  40.0  0.99803  3.29       0.55
# 4                 14.0                  31.0  0.99680  3.50       0.67
#
#    alcohol  quality
# 0     10.4        6
# 1      9.6        5
# 2     10.1        6
# ...

# %%
# hand written test input
single_input = [7.8, 0.58, 0.02, 2, 0.073, 9, 18, 0.9968, 3.36, 0.57, 9.5]
headers = {}
headers["Host"] = f"{MODEL_NAME}.kserve-inference.example.com"
url = f"http://kserve-gateway.local:30200/v1/models/{MODEL_NAME}:predict"

# do a POST, print the response
req_data={"instances": [single_input]}
response = requests.post(url, json=req_data, headers=headers)
print('status code', response) 
print(response.json()) # this will error if the model is not deployed

# %%
# send actual data, 10 rows, remove last column since it is the predicted variable
inputs = data.iloc[:10, :-1].values.tolist()
req_data={"instances": inputs}
response = requests.post(url, json=req_data, headers=headers)
print('status code', response) 
print(response.json()) # this will error if the model is not deployed

# %%
# Spam the endpoint
# Send 30 requests in every 0.5s, each request has one input(i.e., data point)
def send_requests(count=30, input_length=1):
    """
    Send requests to a inference service for predicting wine quality score in every 0.5s
    Args; 
        count: Number of requests
        input_length: Number of inputs in each request
    """
    for _ in range(count):
        req_data={"instances": [single_input for _ in range(input_length)]}
        requests.post(url, json=req_data, headers=headers)
        time.sleep(0.5)
send_requests(count=3, input_length=1)
